# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %% [markdown]
# TO TYPE ENTER
# from selenium.webdriver.common.keys import Keys
#
# element = driver.find_elements_by_class_name("q")
# element.send_keys(Keys.RETURN)
#
# TO USE SELECT
#
# from selenium.webdriver.support.ui import Select
#
# select = Select(driver.find_element_by_name('phy_city'))
# select.select_by_visible_text('Houston')

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages.
#
# ### How will you identify the checkbox to check it?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?
#
# - *TIP: I have a secret awesome way to do this, but you have to ask.*

# %%
from selenium import webdriver

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")

driver = webdriver.Chrome(chrome_options=chrome_options)
driver.get('https://jportal.mdcourts.gov/license/index_disclaimer.jsp')

# %%
check_box = driver.find_element_by_xpath('//*[@id="checkbox"]')

# %%
check_box.click()

# %%
enter_box = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')

# %%
enter_box.click()

# %%
from selenium.webdriver.support.ui import Select

image = (driver.find_element_by_xpath('/html/body/table[1]/tbody/tr[2]/td[2]/table/tbody/tr/td[3]/a/img'))

# %%
image.click()

# %% [markdown]
# ### Once you're on the next page, how will you click the "SEARCH LICENSE RECORDS" link or follow its URL?

# %%
#I will click it

# %% [markdown]
# ### Now you're on the form page. How do you pick "Statewide" for the jurisdiction dropdown?

# %%
select = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')

# %%
search_input = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
search_input.send_keys("Statewide")

# %% [markdown]
# ### How do you type "vap%" into the Trade Name field?

# %%
type = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
search_input = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
search_input.send_keys("vap%")

# %% [markdown]
# ### How do you click the submit button or submit the form?

# %%
submit = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
submit.click()

# %% [markdown]
# ### How can you find and click the 'Next' button on the search results page?

# %%
while True:
    try:
        driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr').click()
    except:
        
        break

# %% [markdown]
# # Okay, let's scrape!
#
# ### Use Selenium to search for vape shops statewide, and then click through until it reaches the last page.
#
# Don't scrape yet!

# %%
#next
while True:
    try:
        driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr').click()
    except:
        
        break

# %%
#back
while True:
    try:
        driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[1]/a/nobr').click()
    except:
        
        break

# %% [markdown]
# ### Use Selenium to scrape the first page of search results for vape shops statewide (well, we'll try).
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source)`*
#
# I've included some BeautifulSoup code that might be helpful. If you use it, **ask me how I made it.** It's important.

# %%
from bs4 import BeautifulSoup
doc = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# IF YOU ARE USING BEAUTIFULSOUP, HERE IS SOME SAMPLE CODE
# IF YOU USE THIS CODE, ASK ME HOW I MADE IT. IT'S IMPORTANT.
business_headers = doc.find_all('tr',class_='searchfieldtitle')
len(business_headers)
# Out:
# 5

# %%
# You'll probably need to find specific tds inside
# of the rows instead of looking at the whole thing.
vape_results = []

for header in business_headers:
    dic = {}
    rows = header.find_next_siblings('tr')
    dic['Header'] = header.find_all('td')[1].text.strip()
    print("HEADER is", header.text.strip())
    link = header.find('a')
    if link:
        url = header.find('a')['href']
        dic['Details'] = "https://jportal.mdcourts.gov/license/" +url
    print("More details", "https://jportal.mdcourts.gov/license/" +url)
    dic['name'] = rows[0].find_all('td')[1].text.strip()
    print("ROW 0 IS", rows[0].text.strip())
    dic['Status'] = rows[0].find_all('td')[2].text.strip().replace('Lic. Status: ', '')
    print("ROW 1 IS", rows[1].text.strip())
    dic['Address'] = rows[1].find_all('td')[1].text.strip() + rows[2].find_all('td')[1].text.strip()
    print("ROW 2 IS", rows[2].text.strip())
    dic['County'] = rows[3].text.strip()
    print("ROW 3 IS", rows[3].text.strip())
    dic['lisence'] = rows[1].find_all('td')[2].text.strip().replace('License: ', '')
    dic['Issued Date'] = rows[2].find_all('td')[2].text.strip().replace('Issued Date: ', '')
    vape_results.append(dic)
    print("----")
# Out:
# HEADER is 1.
# VAPE IT STORE I
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=LdzVt5WuXSE%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1724 N SALISBURY BLVD UNIT 2
# License: 22173807
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 2.
# VAPE IT STORE II
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=53oEnanNtSQ%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1015 S SALISBURY BLVD
# License: 22173808
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 3.
# VAPEPAD THE
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oCr%2FKGeVmPg%3D
# ROW 0 IS ANJ DISTRIBUTIONS LLC
# Lic. Status: Issued
# ROW 1 IS 2299 JOHNS HOPKINS ROAD
# License: 02104436
# ROW 2 IS GAMBRILLS, MD 21054
# Issued Date: 4/05/2017
# ROW 3 IS Anne Arundel County
# ----
# HEADER is 4.
# VAPE FROG
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=WmjynRfJAF8%3D
# ROW 0 IS COX TRADING COMPANY L L C
# Lic. Status: Issued
# ROW 1 IS 110 S. PINEY RD
# License: 17165957
# ROW 2 IS CHESTER, MD 21619
# Issued Date: 5/31/2017
# ROW 3 IS Queen Anne's County
# ----
# HEADER is 5.
# VAPE FROG
# Pending *
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=WmjynRfJAF8%3D
# ROW 0 IS COX TRADING LLC
# Lic. Status: Pending
# ROW 1 IS 346 RITCHIE HIGHWAY
# ROW 2 IS SEVERNA PARK, MD 21146
# ROW 3 IS Anne Arundel County
# ----

# %% [markdown]
# ### Save these into `vape-results.csv`

# %%
import pandas as pd
df = pd.DataFrame(vape_results)

# %%
df.to_csv("vape-results.csv", index = False)

# %% [markdown]
# ### Open `vape-results.csv` to make sure there aren't any extra weird columns

# %%
df = pd.read_csv("vape-results.csv")
df.head()
#len(df)
# Out:
#                                            Address               County  \
# 0  1724 N SALISBURY BLVD UNIT 2SALISBURY, MD 21801      Wicomico County
# 1         1015 S SALISBURY BLVDSALISBURY, MD 21801      Wicomico County
# 2       2299 JOHNS HOPKINS ROADGAMBRILLS, MD 21054  Anne Arundel County
# 3                 110 S. PINEY RDCHESTER, MD 21619  Queen Anne's County
# 4        346 RITCHIE HIGHWAYSEVERNA PARK, MD 21146  Anne Arundel County
#
#                                              Details            Header  \
# 0  https://jportal.mdcourts.gov/license/pbLicense...   VAPE IT STORE I
# 1  https://jportal.mdcourts.gov/license/pbLicense...  VAPE IT STORE II
# 2  https://jportal.mdcourts.gov/license/pbLicense...       VAPEPAD THE
# 3  https://jportal.mdcourts.gov/license/pbLicense...         VAPE FROG
# 4                                                NaN         VAPE FROG
#
#   Issued Date   Status     lisence                       name
# 0   4/27/2017   Issued  22173807.0                AMIN NARGIS
# 1   4/27/2017   Issued  22173808.0                AMIN NARGIS
# 2   4/05/2017   Issued   2104436.0      ANJ DISTRIBUTIONS LLC
# 3   5/31/2017   Issued  17165957.0  COX TRADING COMPANY L L C
# 4         NaN  Pending         NaN            COX TRADING LLC

# %% [markdown]
# ## Use Selenium to scrape ALL pages of results, save the results into `vape-results-all.csv`.

# %%
vape_results_all = []

while True:
    doc = BeautifulSoup(driver.page_source, 'html.parser')
    business_headers = doc.find_all('tr',class_='searchfieldtitle')
    for header in business_headers:
        dic = {}
        rows = header.find_next_siblings('tr')
        dic['Header'] = header.find_all('td')[1].text.strip()
        print("HEADER is", header.text.strip())
        link = header.find('a')
        if link:
            url = header.find('a')['href']
            dic['Details'] = "https://jportal.mdcourts.gov/license/" +url
            print("More details", "https://jportal.mdcourts.gov/license/" +url)
        dic['name'] = rows[0].find_all('td')[1].text.strip()
        print("ROW 0 IS", rows[0].text.strip())
        dic['Status'] = rows[0].find_all('td')[2].text.strip().replace('Lic. Status: ', '')
        print("ROW 1 IS", rows[1].text.strip())
        dic['Address'] = rows[1].find_all('td')[1].text.strip() + rows[2].find_all('td')[1].text.strip()
        print("ROW 2 IS", rows[2].text.strip())
        dic['County'] = rows[3].text.strip()
        print("ROW 3 IS", rows[3].text.strip())
        dic['lisence'] = rows[1].find_all('td')[2].text.strip().replace('License: ', '')
        dic['Issued Date'] = rows[2].find_all('td')[2].text.strip().replace('Issued Date: ', '')
        vape_results_all.append(dic)
        print("----")
    try:
        driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr').click()
    except:
        
        break
# Out:
# HEADER is 1.
# VAPE IT STORE I
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=LdzVt5WuXSE%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1724 N SALISBURY BLVD UNIT 2
# License: 22173807
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 2.
# VAPE IT STORE II
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=53oEnanNtSQ%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1015 S SALISBURY BLVD
# License: 22173808
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 3.
# VAPEPAD THE
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oCr%2FKGeVmPg%3D
# ROW 0 IS ANJ DISTRIBUTIONS LLC
# Lic. Status: Issued
# ROW 1 IS 2299 JOHNS HOPKINS ROAD
# License: 02104436
# ROW 2 IS GAMBRILLS, MD 21054
# Issued Date: 4/05/2017
# ROW 3 IS Anne Arundel County
# ----
# HEADER is 4.
# VAPE FROG
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=WmjynRfJAF8%3D
# ROW 0 IS COX TRADING COMPANY L L C
# Lic. Status: Issued
# ROW 1 IS 110 S. PINEY RD
# License: 17165957
# ROW 2 IS CHESTER, MD 21619
# Issued Date: 5/31/2017
# ROW 3 IS Queen Anne's County
# ----
# HEADER is 5.
# VAPE FROG
# Pending *
# ROW 0 IS COX TRADING LLC
# Lic. Status: Pending
# ROW 1 IS 346 RITCHIE HIGHWAY
# ROW 2 IS SEVERNA PARK, MD 21146
# ROW 3 IS Anne Arundel County
# ----
# HEADER is 6.
# VAPE LOFT (THE)
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=A7vLuODJjMQ%3D
# ROW 0 IS DISBROW II EMERSON HARRINGTON
# Lic. Status: Issued
# ROW 1 IS 185 MITCHELLS CHANCE RD
# License: 02102408
# ROW 2 IS EDGEWATER, MD 21037
# Issued Date: 4/13/2017
# ROW 3 IS Anne Arundel County
# ----
# HEADER is 7.
# VAPE N CIGAR
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2BqOPOkya52A%3D
# ROW 0 IS DISCOUNT TOBACCO ESSEX LLC
# Lic. Status: Issued
# ROW 1 IS 7104 MINSTREL UNIT #7
# License: 13141786
# ROW 2 IS COLUMBIA, MD 21045
# Issued Date: 5/19/2017
# ROW 3 IS Howard County
# ----
# HEADER is 8.
# VAPE DOJO
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=JpHbaNMHPxo%3D
# ROW 0 IS FAIRGROUND VILLAGE LLC
# Lic. Status: Issued
# ROW 1 IS 330 ONE FORTY VILLAGE ROAD
# License: 06126253
# ROW 2 IS WESTMINSTER, MD 21157
# Issued Date: 4/21/2017
# ROW 3 IS Carroll County
# ----
# HEADER is 9.
# VAPE HAVEN
# Pending *
# ROW 0 IS GRIMM JENNIFER
# Lic. Status: Pending
# ROW 1 IS 29890 THREE NOTCH ROAD
# ROW 2 IS CHARLOTTE HALL, MD 20622
# ROW 3 IS St. Mary's County
# ----
# HEADER is 10.
# VAPE BIRD
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XWx1BH7ygIo%3D
# ROW 0 IS HUTCH VAPES LLC
# Lic. Status: Issued
# ROW 1 IS 356 ROMANCOKE ROAD
# License: 17166688
# ROW 2 IS STEVENSVILLE, MD 21666
# Issued Date: 4/13/2017
# ROW 3 IS Queen Anne's County
# ----
# HEADER is 11.
# VAPE FROG
# Pending *
# ROW 0 IS HUTCHINS COX LLP
# Lic. Status: Pending
# ROW 1 IS 110 S PINEY ROAD  STE 106
# ROW 2 IS CHESTER, MD 21619
# ROW 3 IS Queen Anne's County
# ----
# HEADER is 12.
# VAPORS LOUNGE
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=3gp950hoDI0%3D
# ROW 0 IS JAMESON WILLIAM
# Lic. Status: Issued
# ROW 1 IS 28943 THREE NOTCH ROAD
# License: 18167503
# ROW 2 IS MECHANICSVILLE, MD 20659
# Issued Date: 5/17/2017
# ROW 3 IS St. Mary's County
# ----
# HEADER is 13.
# VAPORS LOUNGE
# Pending *
# ROW 0 IS JAMESON WILLIAM E
# Lic. Status: Pending
# ROW 1 IS 6843 CRAIN HIGHWAY
# ROW 2 IS LA PLATA, MD 20646
# ROW 3 IS Charles County
# ----
# HEADER is 14.
# VAPIST MD
# Pending *
# ROW 0 IS JEFFERS MICHAEL
# Lic. Status: Pending
# ROW 1 IS 6321 OLD BRANCH AVE
# ROW 2 IS CAMP SPRINGS, MD 20748
# ROW 3 IS St. Mary's County
# ----
# HEADER is 15.
# VAPIST MD LLC
# Pending *
# ROW 0 IS JEFFERS MICHAEL W
# Lic. Status: Pending
# ROW 1 IS 6321 OLD BRANCH AVE
# ROW 2 IS CAMP SPRINGS, MD 20748
# ROW 3 IS Prince George's County
# ----
# HEADER is 16.
# VAPERTETMD
# Pending *
# ROW 0 IS SHIN JENNY Y
# Lic. Status: Pending
# ROW 1 IS 7954 B AND A BLVD
# ROW 2 IS GLEN BURNIE, MD 21060
# ROW 3 IS Anne Arundel County
# ----
# HEADER is 17.
# VAPERTEKMD
# Pending *
# ROW 0 IS SHIN JENNY YOUNG
# Lic. Status: Pending
# ROW 1 IS 6325 WASHINGTON BLVD
# ROW 2 IS ELKRIDGE, MD 21075
# ROW 3 IS Howard County
# ----
# HEADER is 18.
# VAPORIOT
# Pending *
# ROW 0 IS TAYLOR TRAVIS
# Lic. Status: Pending
# ROW 1 IS 3203 NORTH POINT RD
# ROW 2 IS BALTIMORE, MD 21222
# ROW 3 IS Baltimore County
# ----
# HEADER is 19.
# VAPE PLUS
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=644WqYLGDz4%3D
# ROW 0 IS TRUE ENTERPRISE INC
# Lic. Status: Issued
# ROW 1 IS 519 LINDEN AVENUE UNIT 6
# License: 23178140
# ROW 2 IS POCOMOKE CITY, MD 21851
# Issued Date: 5/05/2017
# ROW 3 IS Worcester County
# ----
# HEADER is 20.
# VAPE  SOCIAL
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZYinLZPQWAo%3D
# ROW 0 IS VAPE  SOCIAL  LLC
# Lic. Status: Issued
# ROW 1 IS 16521 S FREDERICK AVE
# License: 15155429
# ROW 2 IS GAITHERSBURG, MD 20877
# Issued Date: 4/18/2017
# ROW 3 IS Montgomery County
# ----
# HEADER is 21.
# VAPE JUNGLE
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=EI%2BcmhfF3vM%3D
# ROW 0 IS VAPE JUNGLE LLC
# Lic. Status: Issued
# ROW 1 IS 2070 CRAIN HIGHWAY  UNIT F
# License: 08131285
# ROW 2 IS WALDORF, MD 20601
# Issued Date: 3/31/2017
# ROW 3 IS Charles County
# ----
# HEADER is 22.
# VAPE TIME
# Pending *
# ROW 0 IS VAPE TIME LLC
# Lic. Status: Pending
# ROW 1 IS 4130 E JOPPA RD UNIT 109
# ROW 2 IS NOTTINGHAM, MD 21236
# ROW 3 IS Baltimore County
# ----
# HEADER is 23.
# VAPEBAR EXPESS
# Pending *
# ROW 0 IS VAPEBAR EXPRESS LLC
# Lic. Status: Pending
# ROW 1 IS 11110 MALL CIRCLE
# ROW 2 IS WALDORF, MD 20603
# ROW 3 IS Charles County
# ----
# HEADER is 24.
# VAPOR 99
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tIHNtHpYkbk%3D
# ROW 0 IS VAPOR 99 LLC
# Lic. Status: Issued
# ROW 1 IS 3524 CRAIN HWY
# License: 16165362
# ROW 2 IS BOWIE, MD 20716
# Issued Date: 5/03/2017
# ROW 3 IS Prince George's County
# ----
# HEADER is 25.
# VAPOR ALLEY
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=kTXh%2FxMEyJY%3D
# ROW 0 IS VAPOR ALLEY LLC
# Lic. Status: Issued
# ROW 1 IS 8117 OCEAN GATEWAY UNIT #4
# License: 20170900
# ROW 2 IS EASTON, MD 21601
# Issued Date: 5/10/2017
# ROW 3 IS Talbot County
# ----
# HEADER is 26.
# VAPOR EMPORIUM
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=e6ccfYlPJM8%3D
# ROW 0 IS VAPOR EMPORIUM MD LLC
# Lic. Status: Issued
# ROW 1 IS 11717 OLD NATIONAL PIKE
# License: 10135432
# ROW 2 IS NEW MARKET, MD 21774
# Issued Date: 4/14/2017
# ROW 3 IS Frederick County
# ----
# HEADER is 27.
# VAPOR VILLA
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=t2LfIHcgYE8%3D
# ROW 0 IS VAPOR VILLA CORP
# Lic. Status: Issued
# ROW 1 IS 1913 LANSDOWNE ROAD SUITE E
# License: 03121958
# ROW 2 IS BALTIMORE, MD 21227
# Issued Date: 4/12/2017
# ROW 3 IS Baltimore County
# ----
# HEADER is 28.
# VAPOR VILLA
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ccJHsJod51o%3D
# ROW 0 IS VAPOR VILLA CORP
# Lic. Status: Issued
# ROW 1 IS 730 FREDERICK ROAD
# License: 03121959
# ROW 2 IS CATONSVILLE, MD 21228
# Issued Date: 4/12/2017
# ROW 3 IS Baltimore County
# ----
# HEADER is 29.
# VAPE DOJO
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=nCC%2BWKilP88%3D
# ROW 0 IS WALKER TRADING CO INC
# Lic. Status: Issued
# ROW 1 IS 138 N BOND STREET
# License: 12140135
# ROW 2 IS BEL AIR, MD 21014
# Issued Date: 4/03/2017
# ROW 3 IS Harford County
# ----
# HEADER is 30.
# VAPE DOJO
# Pending *
# ROW 0 IS WALKER TRADING COMPANY INC
# Lic. Status: Pending
# ROW 1 IS 11600 CROSSROAD CIR  STE E
# ROW 2 IS BALTIMORE, MD 21220
# ROW 3 IS Baltimore County
# ----
# HEADER is 31.
# VAPE DOJO
# More details https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Xd5m9930Mds%3D
# ROW 0 IS WALKER TRADING COMPANY INC
# Lic. Status: Issued
# ROW 1 IS 3570 SAINT JOHNS LANE, SUITE 109
# License: 13144108
# ROW 2 IS ELLICOTT CITY, MD 21042
# Issued Date: 3/27/2017
# ROW 3 IS Howard County
# ----
# HEADER is 32.
# VAPEZ YARDHOUSE
# Pending *
# ROW 0 IS YARKHOUSE EMPIRE INC
# Lic. Status: Pending
# ROW 1 IS 3315 PLAZA WAY
# ROW 2 IS WALDORF, MD 20603
# ROW 3 IS Charles County
# ----

# %%
df_all = pd.DataFrame(vape_results_all)

# %%
df_all.to_csv("vaper-results-all.csv", index = False)
df_all = pd.read_csv("vaper-results-all.csv")

# %%
df_all
# Out:
#                                               Address                  County  \
# 0     1724 N SALISBURY BLVD UNIT 2SALISBURY, MD 21801         Wicomico County
# 1            1015 S SALISBURY BLVDSALISBURY, MD 21801         Wicomico County
# 2          2299 JOHNS HOPKINS ROADGAMBRILLS, MD 21054     Anne Arundel County
# 3                    110 S. PINEY RDCHESTER, MD 21619     Queen Anne's County
# 4           346 RITCHIE HIGHWAYSEVERNA PARK, MD 21146     Anne Arundel County
# 5          185 MITCHELLS CHANCE RDEDGEWATER, MD 21037     Anne Arundel County
# 6             7104 MINSTREL UNIT #7COLUMBIA, MD 21045           Howard County
# 7     330 ONE FORTY VILLAGE ROADWESTMINSTER, MD 21157          Carroll County
# 8      29890 THREE NOTCH ROADCHARLOTTE HALL, MD 20622       St. Mary's County
# 9            356 ROMANCOKE ROADSTEVENSVILLE, MD 21666     Queen Anne's County
# 10         110 S PINEY ROAD  STE 106CHESTER, MD 21619     Queen Anne's County
# 11     28943 THREE NOTCH ROADMECHANICSVILLE, MD 20659       St. Mary's County
# 12               6843 CRAIN HIGHWAYLA PLATA, MD 20646          Charles County
# 13          6321 OLD BRANCH AVECAMP SPRINGS, MD 20748       St. Mary's County
# 14          6321 OLD BRANCH AVECAMP SPRINGS, MD 20748  Prince George's County
# 15             7954 B AND A BLVDGLEN BURNIE, MD 21060     Anne Arundel County
# 16             6325 WASHINGTON BLVDELKRIDGE, MD 21075           Howard County
# 17             3203 NORTH POINT RDBALTIMORE, MD 21222        Baltimore County
# 18    519 LINDEN AVENUE UNIT 6POCOMOKE CITY, MD 21851        Worcester County
# 19        16521 S FREDERICK AVEGAITHERSBURG, MD 20877       Montgomery County
# 20        2070 CRAIN HIGHWAY  UNIT FWALDORF, MD 20601          Charles County
# 21       4130 E JOPPA RD UNIT 109NOTTINGHAM, MD 21236        Baltimore County
# 22                 11110 MALL CIRCLEWALDORF, MD 20603          Charles County
# 23                      3524 CRAIN HWYBOWIE, MD 20716  Prince George's County
# 24         8117 OCEAN GATEWAY UNIT #4EASTON, MD 21601           Talbot County
# 25        11717 OLD NATIONAL PIKENEW MARKET, MD 21774        Frederick County
# 26     1913 LANSDOWNE ROAD SUITE EBALTIMORE, MD 21227        Baltimore County
# 27            730 FREDERICK ROADCATONSVILLE, MD 21228        Baltimore County
# 28                 138 N BOND STREETBEL AIR, MD 21014          Harford County
# 29      11600 CROSSROAD CIR  STE EBALTIMORE, MD 21220        Baltimore County
# 30  3570 SAINT JOHNS LANE, SUITE 109ELLICOTT CITY,...           Howard County
# 31                    3315 PLAZA WAYWALDORF, MD 20603          Charles County
#
#                                               Details            Header  \
# 0   https://jportal.mdcourts.gov/license/pbLicense...   VAPE IT STORE I
# 1   https://jportal.mdcourts.gov/license/pbLicense...  VAPE IT STORE II
# 2   https://jportal.mdcourts.gov/license/pbLicense...       VAPEPAD THE
# 3   https://jportal.mdcourts.gov/license/pbLicense...         VAPE FROG
# 4                                                 NaN         VAPE FROG
# 5   https://jportal.mdcourts.gov/license/pbLicense...   VAPE LOFT (THE)
# 6   https://jportal.mdcourts.gov/license/pbLicense...      VAPE N CIGAR
# 7   https://jportal.mdcourts.gov/license/pbLicense...         VAPE DOJO
# 8                                                 NaN        VAPE HAVEN
# 9   https://jportal.mdcourts.gov/license/pbLicense...         VAPE BIRD
# 10                                                NaN         VAPE FROG
# 11  https://jportal.mdcourts.gov/license/pbLicense...     VAPORS LOUNGE
# 12                                                NaN     VAPORS LOUNGE
# 13                                                NaN         VAPIST MD
# 14                                                NaN     VAPIST MD LLC
# 15                                                NaN        VAPERTETMD
# 16                                                NaN        VAPERTEKMD
# 17                                                NaN          VAPORIOT
# 18  https://jportal.mdcourts.gov/license/pbLicense...         VAPE PLUS
# 19  https://jportal.mdcourts.gov/license/pbLicense...      VAPE  SOCIAL
# 20  https://jportal.mdcourts.gov/license/pbLicense...       VAPE JUNGLE
# 21                                                NaN         VAPE TIME
# 22                                                NaN    VAPEBAR EXPESS
# 23  https://jportal.mdcourts.gov/license/pbLicense...          VAPOR 99
# 24  https://jportal.mdcourts.gov/license/pbLicense...       VAPOR ALLEY
# 25  https://jportal.mdcourts.gov/license/pbLicense...    VAPOR EMPORIUM
# 26  https://jportal.mdcourts.gov/license/pbLicense...       VAPOR VILLA
# 27  https://jportal.mdcourts.gov/license/pbLicense...       VAPOR VILLA
# 28  https://jportal.mdcourts.gov/license/pbLicense...         VAPE DOJO
# 29                                                NaN         VAPE DOJO
# 30  https://jportal.mdcourts.gov/license/pbLicense...         VAPE DOJO
# 31                                                NaN   VAPEZ YARDHOUSE
#
#    Issued Date   Status     lisence                           name
# 0    4/27/2017   Issued  22173807.0                    AMIN NARGIS
# 1    4/27/2017   Issued  22173808.0                    AMIN NARGIS
# 2    4/05/2017   Issued   2104436.0          ANJ DISTRIBUTIONS LLC
# 3    5/31/2017   Issued  17165957.0      COX TRADING COMPANY L L C
# 4          NaN  Pending         NaN                COX TRADING LLC
# 5    4/13/2017   Issued   2102408.0  DISBROW II EMERSON HARRINGTON
# 6    5/19/2017   Issued  13141786.0     DISCOUNT TOBACCO ESSEX LLC
# 7    4/21/2017   Issued   6126253.0         FAIRGROUND VILLAGE LLC
# 8          NaN  Pending         NaN                 GRIMM JENNIFER
# 9    4/13/2017   Issued  17166688.0                HUTCH VAPES LLC
# 10         NaN  Pending         NaN               HUTCHINS COX LLP
# 11   5/17/2017   Issued  18167503.0                JAMESON WILLIAM
# 12         NaN  Pending         NaN              JAMESON WILLIAM E
# 13         NaN  Pending         NaN                JEFFERS MICHAEL
# 14         NaN  Pending         NaN              JEFFERS MICHAEL W
# 15         NaN  Pending         NaN                   SHIN JENNY Y
# 16         NaN  Pending         NaN               SHIN JENNY YOUNG
# 17         NaN  Pending         NaN                  TAYLOR TRAVIS
# 18   5/05/2017   Issued  23178140.0            TRUE ENTERPRISE INC
# 19   4/18/2017   Issued  15155429.0              VAPE  SOCIAL  LLC
# 20   3/31/2017   Issued   8131285.0                VAPE JUNGLE LLC
# 21         NaN  Pending         NaN                  VAPE TIME LLC
# 22         NaN  Pending         NaN            VAPEBAR EXPRESS LLC
# 23   5/03/2017   Issued  16165362.0                   VAPOR 99 LLC
# 24   5/10/2017   Issued  20170900.0                VAPOR ALLEY LLC
# 25   4/14/2017   Issued  10135432.0          VAPOR EMPORIUM MD LLC
# 26   4/12/2017   Issued   3121958.0               VAPOR VILLA CORP
# 27   4/12/2017   Issued   3121959.0               VAPOR VILLA CORP
# 28   4/03/2017   Issued  12140135.0          WALKER TRADING CO INC
# 29         NaN  Pending         NaN     WALKER TRADING COMPANY INC
# 30   3/27/2017   Issued  13144108.0     WALKER TRADING COMPANY INC
# 31         NaN  Pending         NaN           YARKHOUSE EMPIRE INC

# %%
len(df_all)
# Out:
# 32
